# %% [markdown]
# #  Project 1 (M6): Exploratory Data Analysis Using Matplotlib & Seaborn
#
#   # ..............................CRIME DATA OF LOS ANGELES..................................

# %%
# First and foremost thing to do is Importing the libraries.

import Data_summary as ds

# %% [markdown]
# Getting Data details to look for first 5 rows

# %%
ds.data.details_H()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0   10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230     3
# 1  190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330     1
# 2  200110444  04/14/2020 12:00:00 AM  02/13/2020 12:00:00 AM      1200     1
# 3  191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730    15
# 4  191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415    19
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0    Southwest          377         2     624
# 1      Central          163         2     624
# 2      Central          155         2     845
# 3  N Hollywood         1543         2     745
# 4      Mission         1998         2     740
#
#                                          Crm Cd Desc         Mocodes  \
# 0                           BATTERY - SIMPLE ASSAULT       0444 0913
# 1                           BATTERY - SIMPLE ASSAULT  0416 1822 1414
# ...

# %%
# To view all the overall info about the dataset
ds.data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 820599 entries, 0 to 820598
# Data columns (total 28 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DR_NO           820599 non-null  int64
#  1   Date Rptd       820599 non-null  object
#  2   DATE OCC        820599 non-null  object
#  3   TIME OCC        820599 non-null  int64
#  4   AREA            820599 non-null  int64
#  5   AREA NAME       820599 non-null  object
#  6   Rpt Dist No     820599 non-null  int64
#  7   Part 1-2        820599 non-null  int64
#  8   Crm Cd          820599 non-null  int64
#  9   Crm Cd Desc     820599 non-null  object
#  10  Mocodes         707114 non-null  object
#  11  Vict Age        820599 non-null  int64
#  12  Vict Sex        712653 non-null  object
#  13  Vict Descent    712645 non-null  object
#  14  Premis Cd       820589 non-null  float64
#  15  Premis Desc     820116 non-null  object
# ...

# %%
#To view last 5 values of the Dataset
ds.data.details_T()
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 820594  231604807  01/27/2023 12:00:00 AM  01/26/2023 12:00:00 AM      1800
# 820595  231606525  03/22/2023 12:00:00 AM  03/22/2023 12:00:00 AM      1000
# 820596  231210064  04/12/2023 12:00:00 AM  04/12/2023 12:00:00 AM      1630
# 820597  230115220  07/02/2023 12:00:00 AM  07/01/2023 12:00:00 AM         1
# 820598  230906458  03/05/2023 12:00:00 AM  03/05/2023 12:00:00 AM       900
#
#         AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 820594    16     Foothill         1663         2     740
# 820595    16     Foothill         1602         1     230
# 820596    12  77th Street         1239         1     230
# 820597     1      Central          154         1     352
# 820598     9     Van Nuys          914         2     745
#
#                                               Crm Cd Desc  \
# 820594  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# ...

# %%
#To View the no of columns
ds.data.attributes()
# Out:
# Index(['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME',
#        'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Mocodes',
#        'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc',
#        'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'Crm Cd 1',
#        'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'LOCATION', 'Cross Street', 'LAT',
#        'LON'],
#       dtype='object')

# %%
# Used to view the Null valuesds.data.null_values()
ds.data.nullvalues()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\aquib\OneDrive\Desktop\project 1\Untitled (1).ipynb Cell 8 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/aquib/OneDrive/Desktop/project%201/Untitled%20%281%29.ipynb#Y142sZmlsZQ%3D%3D?line=0'>1</a> # Used to view the Null valuesds.data.null_values()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aquib/OneDrive/Desktop/project%201/Untitled%20%281%29.ipynb#Y142sZmlsZQ%3D%3D?line=1'>2</a> ds.data.nullvalues()
#
# AttributeError: type object 'data' has no attribute 'nullvalues'

# %%
#To find the percentage of missing values.
ds.data.Missing_values_percentage()
# Out:
# DR_NO              0.000000
# Date Rptd          0.000000
# DATE OCC           0.000000
# TIME OCC           0.000000
# AREA               0.000000
# AREA NAME          0.000000
# Rpt Dist No        0.000000
# Part 1-2           0.000000
# Crm Cd             0.000000
# Crm Cd Desc        0.000000
# Mocodes           13.829532
# Vict Age           0.000000
# Vict Sex          13.154537
# Vict Descent      13.155512
# Premis Cd          0.001219
# Premis Desc        0.058859
# Weapon Used Cd    65.137905
# Weapon Desc       65.137905
# Status             0.000000
# Status Desc        0.000000
# Crm Cd 1           0.001219
# Crm Cd 2          92.637939
# Crm Cd 3          99.753229
# Crm Cd 4          99.992688
# LOCATION           0.000000
# Cross Street      84.009973
# LAT                0.000000
# LON                0.000000
# dtype: float64

# %%
# To see the Dimensions of the Dataset
ds.data.shape()
# Out:
# (820599, 28)

# %%
#To View the statistical Summary
ds.data.describe()
# Out:
#               DR_NO       TIME OCC           AREA    Rpt Dist No  \
# count  8.205990e+05  820599.000000  820599.000000  820599.000000
# mean   2.161299e+08    1335.627492      10.711722    1117.592487
# std    1.083045e+07     654.020941       6.093656     609.360686
# min    8.170000e+02       1.000000       1.000000     101.000000
# 25%    2.102046e+08     900.000000       6.000000     621.000000
# 50%    2.201176e+08    1415.000000      11.000000    1142.000000
# 75%    2.220056e+08    1900.000000      16.000000    1617.000000
# max    2.399165e+08    2359.000000      21.000000    2199.000000
#
#             Part 1-2         Crm Cd       Vict Age      Premis Cd  \
# count  820599.000000  820599.000000  820599.000000  820589.000000
# mean        1.413828     500.803992      29.806031     305.759386
# std         0.492519     207.807715      21.776511     216.670080
# min         1.000000     110.000000      -3.000000     101.000000
# ...

# %%
# To find the Data types
ds.data.data_type()
# Out:
# DR_NO               int64
# Date Rptd          object
# DATE OCC           object
# TIME OCC            int64
# AREA                int64
# AREA NAME          object
# Rpt Dist No         int64
# Part 1-2            int64
# Crm Cd              int64
# Crm Cd Desc        object
# Mocodes            object
# Vict Age            int64
# Vict Sex           object
# Vict Descent       object
# Premis Cd         float64
# Premis Desc        object
# Weapon Used Cd    float64
# Weapon Desc        object
# Status             object
# Status Desc        object
# Crm Cd 1          float64
# Crm Cd 2          float64
# Crm Cd 3          float64
# Crm Cd 4          float64
# LOCATION           object
# Cross Street       object
# LAT               float64
# LON               float64
# dtype: object

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# #### Importing EDA.py file

# %%
import EDA_FILE as df

# %% [markdown]
# ### Data Cleaning

# %%
df.EDA_Exploration.Cleaning()
# Out:
#                       DATE OCC  TIME OCC  AREA    AREA NAME  Rpt Dist No  \
# 0       01/08/2020 12:00:00 AM      2230     3    Southwest          377
# 1       01/01/2020 12:00:00 AM       330     1      Central          163
# 2       02/13/2020 12:00:00 AM      1200     1      Central          155
# 3       01/01/2020 12:00:00 AM      1730    15  N Hollywood         1543
# 4       01/01/2020 12:00:00 AM       415    19      Mission         1998
# ...                        ...       ...   ...          ...          ...
# 820594  01/26/2023 12:00:00 AM      1800    16     Foothill         1663
# 820595  03/22/2023 12:00:00 AM      1000    16     Foothill         1602
# 820596  04/12/2023 12:00:00 AM      1630    12  77th Street         1239
# 820597  07/01/2023 12:00:00 AM         1     1      Central          154
# 820598  03/05/2023 12:00:00 AM       900     9     Van Nuys          914
#
#         Crm Cd                                        Crm Cd Desc  Vict Age  \
# ...

# %% [markdown]
# ### Viewing the Outliers using the Box Plot.

# %%
df.EDA_Exploration.Outlier_check()

# %% [markdown]
# The output gives us two boxplots of victim age and Time Occ with the Outliers in Victim age and the Median

# %%
df.EDA_Exploration.Binning()
# Out:
#                       DATE OCC  TIME OCC  AREA    AREA NAME  Rpt Dist No  \
# 0       01/08/2020 12:00:00 AM      2230     3    Southwest          377
# 1       01/01/2020 12:00:00 AM       330     1      Central          163
# 2       02/13/2020 12:00:00 AM      1200     1      Central          155
# 3       01/01/2020 12:00:00 AM      1730    15  N Hollywood         1543
# 4       01/01/2020 12:00:00 AM       415    19      Mission         1998
# ...                        ...       ...   ...          ...          ...
# 820594  01/26/2023 12:00:00 AM      1800    16     Foothill         1663
# 820595  03/22/2023 12:00:00 AM      1000    16     Foothill         1602
# 820596  04/12/2023 12:00:00 AM      1630    12  77th Street         1239
# 820597  07/01/2023 12:00:00 AM         1     1      Central          154
# 820598  03/05/2023 12:00:00 AM       900     9     Van Nuys          914
#
#         Crm Cd                                        Crm Cd Desc  Vict Age  \
# ...

# %% [markdown]
# ### Data Analysis and Visualization
#
# ### Below Graph shows the crimes reported throughout the day,reveals distinct Temporal patterns.

# %%
df.EDA_Exploration.Crime_by_Time()

# %% [markdown]
# ### Below Graph, we've crafted a comprehensive visualization that encapsulates the demographics of crime victims, distinctly highlighting gender disparities across age groups.

# %%
df.EDA_Exploration.Crime_by_Gender()

# %% [markdown]
# ### Overall purpose of this Graph is to show the count of the occurrences of Crimes across Different areas, showing the Highest number of count per area.

# %%
df.EDA_Exploration.Crime_by_Area()
# Out:
# The most notorious area for crimes is AREA         1
# Count    55209
# Name: 0, dtype: int64 (Area 1) with 55209 reported crimes.

# %% [markdown]
# #### In this Histogram, we will see the Crime Trend going from 2020 till present, and we use histogram because its a continous data.

# %%
df.EDA_Exploration.Crime_by_years()

# %% [markdown]
# ### Below is the representation of the Crimes by Year in Line plot, Both Matplotlib and Seaborn.

# %%
df.EDA_Exploration.Crime_line_years()

# %% [markdown]
# ### In the Below Barplot we used it to visualize the Different Crime descriptions by Count i.e Frequency.in both Matplotlib and Seaborn

# %%
df.EDA_Exploration.Crime_by_Count()

# %% [markdown]
# #### INFERENCE
